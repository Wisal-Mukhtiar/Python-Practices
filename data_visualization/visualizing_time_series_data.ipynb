# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# in order to tell the pandas about the dates column, parse_dates is used, informing about time-series
climate_change = pd.read_csv('datasets\climate_change.csv', parse_dates=['date'], index_col='date')

# %% [markdown]
# <font size='5'> Time Series data Visualization </font> <br>
#     Data in the current csv is the collected every month from past century, and is time-series data
#     we will visualize the data using matplotlib. Date is used as indexed from the file

# %%
fig, ax = plt.subplots()
ax.plot(climate_change.index, climate_change['co2'])
ax.set_xlabel('Time')
ax.set_ylabel('CO2 (ppm)')
plt.show()

# %% [markdown]
# zooming on a specific time or say looking for difference in a decade

# %%
fig, ax = plt.subplots()

# Create variable seventies with data from "1970-01-01" to "1979-12-31"
seventies = climate_change['1970-01-01':'1979-12-31']

ax.plot(seventies.index, seventies["co2"])
plt.show()

# %% [markdown]
# <font size='4'> Time series with different variables </font>
# <br> the x axis will be the same but the y axis will be different for both, using ax.twinx() method

# %%
fig, ax = plt.subplots()
ax.plot(climate_change.index, climate_change['co2'], color='blue')
ax2 = ax.twinx()
ax2.plot(climate_change.index, climate_change['relative_temp'], color='red')
plt.show()

# %%
# to make it more clear we add tick parameters
fig, ax = plt.subplots()
ax.plot(climate_change.index, climate_change['co2'], color='blue')
ax.tick_params('y', colors='blue')
ax2 = ax.twinx()
ax2.plot(climate_change.index, climate_change['relative_temp'], color='red')
ax2.tick_params('y', colors='red')
plt.show()

# %% [markdown]
# we can write a function for above code

# %%
# Define a function called plot_timeseries
def plot_timeseries(axes, x, y, color, xlabel, ylabel):

  # Plot the inputs x,y in the provided color
  axes.plot(x, y, color=color)

  # Set the x-axis label
  axes.set_xlabel(xlabel)

  # Set the y-axis label
  axes.set_ylabel(ylabel, color=color)

  # Set the colors tick params for y-axis
  axes.tick_params('y', colors=color)

# %% [markdown]
# <font size='5'> Annotating time series data  </font><br>
# if we want to annotate the date 2015-10-06 at which the y temp was 1 we can use the following syntax

# %%
fig, ax = plt.subplots()
plot_timeseries(ax, climate_change.index, climate_change['co2'], 'blue', 'Time', 'Co2 ppm')
ax2 = ax.twinx()
plot_timeseries(ax2, climate_change.index, climate_change['relative_temp'], 'red', 'Time', 'relative_temp')
ax2.annotate('>1 degree', xy=(pd.Timestamp('2015-10-06'),1)
          )
# Out:
# Text(2015-10-06 00:00:00, 1, '>1 degree')

# %% [markdown]
# the text in above plot is not clear, to make it clear, let's add the place where we can place the text

# %%
fig, ax = plt.subplots()
plot_timeseries(ax, climate_change.index, climate_change['co2'], 'blue', 'Time', 'Co2 ppm')
ax2 = ax.twinx()
plot_timeseries(ax2, climate_change.index, climate_change['relative_temp'], 'red', 'Time', 'relative_temp')
ax2.annotate('>1 degree', xy=(pd.Timestamp('2015-10-06'),1),
    xytext=(pd.Timestamp('2008-10-06'), -0.2))
# Out:
# Text(2008-10-06 00:00:00, -0.2, '>1 degree')

# %% [markdown]
# we change the position of the text but don't know what's the text connected to, let's draw an arrow

# %%
fig, ax = plt.subplots()
plot_timeseries(ax, climate_change.index, climate_change['co2'], 'blue', 'Time', 'Co2 ppm')
ax2 = ax.twinx()
plot_timeseries(ax2, climate_change.index, climate_change['relative_temp'], 'red', 'Time', 'relative_temp')
ax2.annotate('>1 degree', xy=(pd.Timestamp('2015-10-06'),1),
             xytext=
